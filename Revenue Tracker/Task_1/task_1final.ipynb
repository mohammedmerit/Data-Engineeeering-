# %%
import pandas as pd
import os

# %% [markdown]
# `os.chdir` == change directory so python searches only in DE tasks folder
#
# `sheet_name=None` means read all sheets. Output is a dictionary
# `{
#   "April": DataFrame,
#   "May": DataFrame,
#   "June": DataFrame
#  }`
#
# `header=None` means the first row is not a header, so pandas will assign default column names (0, 1, 2, ...)
#
#
# `all sheets looks like this:
# all_sheets["April"]  # DataFrame for April
# all_sheets["May"]    # DataFrame for May
# all_sheets["June"]   # DataFrame for June`

# %%
os.chdir(r'C:\Users\mohammed.ahmed\Desktop\DE tasks')
all_sheets = pd.read_excel('Delta3_Apr.xlsx', sheet_name=None, header=None)

# %%
def to_number(val):
    if isinstance(val, str):
        return float(val.replace('£', '').replace(',', ''))
    return float(val)

# this function changes strings to numbers, eg removing £

# %%
def extract_sheet(df):
    def get(label):
        return to_number(df[df[0] == label][1].values[0])
    
    core        = get('Salary - Core employees')
    tl          = get('Salary - TL / Managers')
    consultants = get('Salary - Consultants')
    incentive   = get('Performance payments - Incentive & Others')
    
    return {
        'revenue':          get('Revenue'),
        'revenue_pct':      get('Revenue %'),
        'total_workforce':  core + tl + consultants + incentive,
        'tech_salary_pct':  (core + tl + consultants + incentive) / get('Revenue'),
        'total_salary':     get('Total salary allocation for project'),
        'total_salary_pct': get('Total salary allocation %'),
    }

# %%
results = {}
for sheet_name, df in all_sheets.items():
    results[sheet_name] = extract_sheet(df)
    print(sheet_name, results[sheet_name])
# Out:
# MI - Apr @ 108  {'revenue': 320000.0, 'revenue_pct': 0.41551917231843205, 'total_workforce': 189255.38027791225, 'tech_salary_pct': 0.5914230633684758, 'total_salary': 234311.3682084915, 'total_salary_pct': 0.732223025651536}
# May {'revenue': 295000.0, 'revenue_pct': 0.4, 'total_workforce': 174000.0, 'tech_salary_pct': 0.5898305084745763, 'total_salary': 217500.0, 'total_salary_pct': 0.74}
# June {'revenue': 345000.0, 'revenue_pct': 0.44, 'total_workforce': 201400.0, 'tech_salary_pct': 0.5837681159420289, 'total_salary': 245500.0, 'total_salary_pct': 0.71}

# %%
from openpyxl import load_workbook

wb = load_workbook('Delta3_Ouptut.xlsx')
ws = wb['Revenue ']

col_map = {
    'MI - Apr @ 108 ': 4,
    'May':             5,
    'June':            6,
}

ROW_REVENUE     = 7
ROW_REVENUE_PCT = 8
ROW_WORKFORCE   = 10
ROW_TECH_PCT    = 11
ROW_SALARY      = 13
ROW_SALARY_PCT  = 14

for sheet_name, data in results.items():
    col = col_map[sheet_name]
    ws.cell(row=ROW_REVENUE,     column=col).value = data['revenue']
    ws.cell(row=ROW_REVENUE_PCT, column=col).value = data['revenue_pct']
    ws.cell(row=ROW_WORKFORCE,   column=col).value = data['total_workforce']
    ws.cell(row=ROW_TECH_PCT, column=col).value = data['tech_salary_pct']
    ws.cell(row=ROW_SALARY,      column=col).value = data['total_salary']
    ws.cell(row=ROW_SALARY_PCT,  column=col).value = data['total_salary_pct']

wb.save('Delta3_Ouptut.xlsx')
print('Done!')
# Out:
# Done!

# %%
for sheet_name, df in all_sheets.items():
    print(df)
# Out:
#                                                    0              1
# 0                                                108         112.86
# 1                                       Project Name    Grand Total
# 2                                                NaN            NaN
# 3                                            Revenue         320000
# 4                                   Production Hours       23179.23
# 5                                      Quality Hours        1404.39
# 6                                        Total Hours       25726.43
# 7                                          Revenue %       0.415519
# 8                                                NaN            NaN
# 9                    Direct Cost : Salary Operations            NaN
# 10                           Salary - Core employees         160000
# 11                                  Salary - Quality              0
# 12                            Salary - TL / Managers              0
# 13                              Salary - Consultants          28000
# 14  IT / Ops Support Cost - Billable project support    3148.329156
# 15                              Gratuity + Insurance     655.583762
# 16         Performance payments - Incentive & Others    1255.380278
# 17             Other Payout - Severance / Settlement              0
# 18                                               NaN            NaN
# 19                                               NaN            NaN
# 20               Total salary allocation for project  234311.368208
# 21                         Total salary allocation %       0.732223
#                                                    0            1
# 0                                       Project Name  Grand Total
# 1                                                NaN          NaN
# 2                                            Revenue     £295,000
# 3                                   Production Hours        21850
# 4                                      Quality Hours         1250
# 5                                        Total Hours        24300
# 6                                          Revenue %          0.4
# 7                                                NaN          NaN
# 8                    Direct Cost : Salary Operations          NaN
# 9                            Salary - Core employees     £148,000
# 10                                  Salary - Quality           £0
# 11                            Salary - TL / Managers           £0
# 12                              Salary - Consultants      £25,000
# 13  IT / Ops Support Cost - Billable project support       £2,900
# 14                              Gratuity + Insurance         £600
# 15         Performance payments - Incentive & Others       £1,000
# 16             Other Payout - Severance / Settlement           £0
# 17                                               NaN          NaN
# 18                                               NaN          NaN
# 19               Total salary allocation for project     £217,500
# 20                         Total salary allocation %         0.74
#                                                    0            1
# 0                                       Project Name  Grand Total
# 1                                                NaN          NaN
# 2                                            Revenue     £345,000
# 3                                   Production Hours        24500
# 4                                      Quality Hours         1500
# 5                                        Total Hours        27000
# 6                                          Revenue %         0.44
# 7                                                NaN          NaN
# 8                    Direct Cost : Salary Operations          NaN
# 9                            Salary - Core employees     £170,000
# 10                                  Salary - Quality           £0
# 11                            Salary - TL / Managers           £0
# 12                              Salary - Consultants      £30,000
# 13  IT / Ops Support Cost - Billable project support       £3,400
# 14                              Gratuity + Insurance         £700
# 15         Performance payments - Incentive & Others       £1,400
# 16             Other Payout - Severance / Settlement           £0
# 17                                               NaN          NaN
# 18                                               NaN          NaN
# 19               Total salary allocation for project     £245,500
# 20                         Total salary allocation %         0.71
